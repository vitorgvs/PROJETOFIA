# %% [markdown]
# ## Bibliotecas necessárias

# %%
import os

# Verificar se o diretório existe
print("Diretório existe?", os.path.exists("/dados_gtfs"))

# Listar arquivos no diretório (se existir)
if os.path.exists("/dados_gtfs"):
    print("Arquivos:", os.listdir("/dados_gtfs"))
else:
    print("Diretório não existe!")

# Verificar diretório atual
print("Diretório atual:", os.getcwd())
# Out:
# Diretório existe? True
# Arquivos: ['agency.txt', 'calendar.txt', 'fare_attributes.txt', 'fare_rules.txt', 'frequencies.txt', 'routes.txt', 'shapes.txt', 'stops.txt', 'stop_times.txt', 'trips.txt']
# Diretório atual: /home/user

# %%
import requests
import json
import pyspark
from delta import *

# %% [markdown]
# ## Configurações spark

# %%
builder = (
    pyspark.sql.SparkSession.builder
    .appName("delta")
    .master("spark://spark-master:7077")
    .config("spark.sql.extensions", "io.delta.sql.DeltaSparkSessionExtension")
    .config("spark.sql.catalog.spark_catalog", "org.apache.spark.sql.delta.catalog.DeltaCatalog")
    .config("spark.hadoop.fs.defaultFS", "file:///")  # Define local como padrão
    .config("spark.hadoop.fs.s3a.access.key", "datalake")
    .config("spark.hadoop.fs.s3a.secret.key", "datalake")
    .config("spark.hadoop.fs.s3a.endpoint", "http://minio:9000")
    .config("spark.hadoop.fs.s3a.path.style.access", "true")
    .config("spark.hadoop.fs.s3a.impl", "org.apache.hadoop.fs.s3a.S3AFileSystem")
)
spark = configure_spark_with_delta_pip(builder).enableHiveSupport().getOrCreate()

# Agora pode usar sem prefixo para local
df = spark.read.csv("/dados_gtfs/stops.txt", header=True)

# %% [markdown]
# ## leitura de dados gtfs

# %%
df = (
    spark.read
    .csv("file:///dados_gtfs/stops.txt", header=True)
)

# %%
df_routes = (
    spark.read
    .csv("file:///dados_gtfs/routes.txt", header=True)
)
df_routes.show()
# Out:
# +--------+---------+----------------+--------------------+----------+-----------+----------------+
# |route_id|agency_id|route_short_name|     route_long_name|route_type|route_color|route_text_color|
# +--------+---------+----------------+--------------------+----------+-----------+----------------+
# | 1012-10|        1|         1012-10|Term. Jd. Britani...|         3|     509E2F|          FFFFFF|
# | 1012-21|        1|         1012-21|Term. Jd. Britâni...|         3|     509E2F|          FFFFFF|
# | 1014-10|        1|         1014-10|Cptm Perus - Morr...|         3|     509E2F|          FFFFFF|
# | 1015-10|        1|         1015-10|Term. Jd. Britâni...|         3|     509E2F|          FFFFFF|
# | 1016-10|        1|         1016-10|Cem. Do Horto - S...|         3|     002F6C|          FFFFFF|
# | 1017-10|        1|         1017-10|Perus - Conexão V...|         3|     509E2F|          FFFFFF|
# | 1018-10|        1|         1018-10|Vl. Rosa - Metrô ...|         3|     002F6C|          FFFFFF|
# | 1019-10|        1|         1019-10|Sol Nascente - Te...|         3|     509E2F|          FFFFFF|
# | 1020-10|        1|         1020-10|Perus - Conexão V...|         3|     509E2F|          FFFFFF|
# | 1021-10|        1|         1021-10|Cohab Brasilândia...|         3|     509E2F|          FFFFFF|
# | 1022-10|        1|         1022-10|Vl. Sta. Cruz - C...|         3|     509E2F|          FFFFFF|
# | 1023-10|        1|         1023-10|Vl. Pirituba - Cp...|         3|     509E2F|          FFFFFF|
# | 1024-10|        1|         1024-10|Jd. Carombé - Con...|         3|     509E2F|          FFFFFF|
# | 1025-10|        1|         1025-10|Jd. Carombé - Con...|         3|     509E2F|          FFFFFF|
# | 1026-10|        1|         1026-10|Vl. Iara - Conexã...|         3|     509E2F|          FFFFFF|
# | 1034-10|        1|         1034-10|Vl. Iara - Conexã...|         3|     509E2F|          FFFFFF|
# | 1036-10|        1|         1036-10|Cohab Brasilândia...|         3|     509E2F|          FFFFFF|
# | 106A-10|        1|         106A-10|Metrô Santana - I...|         3|     002F6C|          FFFFFF|
# | 107T-10|        1|         107T-10|Metrô Tucuruvi - ...|         3|     002F6C|          FFFFFF|
# | 1156-10|        1|         1156-10|Vl. Sabrina - Pça...|         3|     002F6C|          FFFFFF|
# +--------+---------+----------------+--------------------+----------+-----------+----------------+
# only showing top 20 rows

# %% [markdown]
# ## Lista de todas as paradas únicas

# %%
lista = (
    df
    .select('stop_id')
    .distinct()
    .rdd
    .flatMap(lambda x: x)
    .collect()
)
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# Cell In[21], line 3
#       1 lista = (
#       2     df
# ----> 3     .select('route_id')
#       4     .distinct()
#       5     .rdd
#       6     .flatMap(lambda x: x)
#       7     .collect()
#       8 )
#
# File /usr/local/spark/python/pyspark/sql/dataframe.py:2023, in DataFrame.select(self, *cols)
#    2002 def select(self, *cols: "ColumnOrName") -> "DataFrame":  # type: ignore[misc]
#    2003     """Projects a set of expressions and returns a new :class:`DataFrame`.
#    2004
#    2005     .. versionadded:: 1.3.0
#    (...)
#    2021     [Row(name='Alice', age=12), Row(name='Bob', age=15)]
#    2022     """
# -> 2023     jdf = self._jdf.select(self._jcols(*cols))
#    2024     return DataFrame(jdf, self.sparkSession)
#
# File /usr/local/spark/python/lib/py4j-0.10.9.5-src.zip/py4j/java_gateway.py:1321, in JavaMember.__call__(self, *args)
#    1315 command = proto.CALL_COMMAND_NAME +\
#    1316     self.command_header +\
#    1317     args_command +\
#    1318     proto.END_COMMAND_PART
#    1320 answer = self.gateway_client.send_command(command)
# -> 1321 return_value = get_return_value(
#    1322     answer, self.gateway_client, self.target_id, self.name)
#    1324 for temp_arg in temp_args:
#    1325     temp_arg._detach()
#
# File /usr/local/spark/python/pyspark/sql/utils.py:196, in capture_sql_exception.<locals>.deco(*a, **kw)
#     192 converted = convert_exception(e.java_exception)
#     193 if not isinstance(converted, UnknownException):
#     194     # Hide where the exception came from that shows a non-Pythonic
#     195     # JVM exception message.
# --> 196     raise converted from None
#     197 else:
#     198     raise
#
# AnalysisException: Column 'route_id' does not exist. Did you mean one of the following? [stop_id, stop_desc, stop_lat, stop_lon, stop_name];
# 'Project ['route_id]
# +- Relation [stop_id#44,stop_name#45,stop_desc#46,stop_lat#47,stop_lon#48] csv

# %%
lista_linhas = (
    df_routes
    .select('route_id')
    .distinct()
    .rdd
    .flatMap(lambda x: x)
    .collect()
)

# %%
len(lista)
# Out:
# 22073

# %%
len(lista_linhas)
# Out:
# 1345

# %% [markdown]
# ## Autenticação API

# %%
BASE_URL = "http://api.olhovivo.sptrans.com.br/v2.1"
def autenticar():
    auth_url = f"{BASE_URL}/Login/Autenticar"
    params = {"token": "9dac5122b12c0e6aacfc7b6922dead75ce7368011c53b6ee9ea9011f5cc5ac24"}
    session = requests.Session()
    resp = session.post(auth_url, params=params)
    if resp.status_code == 200 and resp.text.lower() == "true":
        return session
    return False

# %%
import json

def previsao_por_parada(codigo_linha, sessao, url:str):
    if url == 'previsao':
        url =  f'{BASE_URL}//Previsao/Linha?codigoLinha={codigo_linha}'
    elif url == 'linha':    
        url = f"{BASE_URL}//Linha/Buscar?termosBusca={codigo_linha}"
    elif url == 'posicao':
        url = f'{BASE_URL}/Posicao'
    response = sessao.get(url)

    # sessão expirada → reautentica e tenta de novo
    if response.status_code == 401:
        ok = autenticar()
        if not ok:
            Exception(f"Falha ao reautenticar na API SPTrans {Exception}")

        response = sessao.get(url, params=params)

    response.raise_for_status()
    return response.json()

# %%
pip install boto3
# Out:
# Collecting boto3
#   Downloading boto3-1.42.24-py3-none-any.whl (140 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 140.6/140.6 kB 1.4 MB/s eta 0:00:00a 0:00:01
# Collecting botocore<1.43.0,>=1.42.24
#   Downloading botocore-1.42.24-py3-none-any.whl (14.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.6/14.6 MB 10.5 MB/s eta 0:00:0000:0100:01
# Collecting s3transfer<0.17.0,>=0.16.0
#   Downloading s3transfer-0.16.0-py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 1.9 MB/s eta 0:00:00ta 0:00:01
# Collecting jmespath<2.0.0,>=0.7.1
#   Downloading jmespath-1.0.1-py3-none-any.whl (20 kB)
# Requirement already satisfied: urllib3!=2.2.0,<3,>=1.25.4 in /opt/conda/lib/python3.10/site-packages (from botocore<1.43.0,>=1.42.24->boto3) (1.26.13)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /opt/conda/lib/python3.10/site-packages (from botocore<1.43.0,>=1.42.24->boto3) (2.8.2)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil<3.0.0,>=2.1->botocore<1.43.0,>=1.42.24->boto3) (1.16.0)
# Installing collected packages: jmespath, botocore, s3transfer, boto3
# Successfully installed boto3-1.42.24 botocore-1.42.24 jmespath-1.0.1 s3transfer-0.16.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import boto3
import json
from datetime import datetime

def upload_json_partitioned(dados, bucket_name, path,  name_doc):
    # 1. Configuração do cliente
    s3 = boto3.client(
        's3',
        endpoint_url='http://minio:9000',
        aws_access_key_id='projetofinal',
        aws_secret_access_key='projetofinal',
        region_name='us-east-1'
    )

    # 2. Gerar variáveis de data para a partição
    now = datetime.now()
    ano = now.strftime('%Y')
    mes = now.strftime('%m')
    dia = now.strftime('%d')
    timestamp = now.strftime('%H%M%S')

    # 3. Montar a KEY (Caminho + Nome do Arquivo)
    # A estrutura de pastas é definida pelas barras '/'
    key = f"{path}/ano={ano}/mes={mes}/dia={dia}/{name_doc}_{timestamp}.json"

    # 4. Converter dados para JSON
    body = json.dumps(dados, ensure_ascii=False, indent=4)

    # 5. Upload
    s3.put_object(
        Bucket=bucket_name,
        Key=key,
        Body=body,
        ContentType='application/json'
    )
    
    print(f"Objeto salvo em: {bucket_name}/{key}")

# Uso:
# upload_json_partitioned(meus_dados, 'raw', 'position')

# %%
import json
import time
sessao = autenticar()        
while True:
    lista_posicoes_veiculo = []
    
    previsao = previsao_por_parada(None, sessao, 'posicao')
    upload_json_partitioned(previsao, 'raw', 'posicao_veiculo','veiculo')
    print(f"linha executada com sucesso !")
    time.sleep(2)
# Out:
# Objeto salvo em: raw/posicao_veiculo/ano=2026/mes=01/dia=08/veiculo_013141.json
# linha executada com sucesso !
# Objeto salvo em: raw/posicao_veiculo/ano=2026/mes=01/dia=08/veiculo_013144.json
# linha executada com sucesso !
# Objeto salvo em: raw/posicao_veiculo/ano=2026/mes=01/dia=08/veiculo_013146.json
# linha executada com sucesso !
# Objeto salvo em: raw/posicao_veiculo/ano=2026/mes=01/dia=08/veiculo_013149.json
# linha executada com sucesso !
# Objeto salvo em: raw/posicao_veiculo/ano=2026/mes=01/dia=08/veiculo_013151.json
# linha executada com sucesso !
# Objeto salvo em: raw/posicao_veiculo/ano=2026/mes=01/dia=08/veiculo_013153.json
# linha executada com sucesso !
# Objeto salvo em: raw/posicao_veiculo/ano=2026/mes=01/dia=08/veiculo_013156.json
# linha executada com sucesso !
# Objeto salvo em: raw/posicao_veiculo/ano=2026/mes=01/dia=08/veiculo_013159.json
# linha executada com sucesso !
# Objeto salvo em: raw/posicao_veiculo/ano=2026/mes=01/dia=08/veiculo_013201.json
# linha executada com sucesso !
# Objeto salvo em: raw/posicao_veiculo/ano=2026/mes=01/dia=08/veiculo_013204.json
# linha executada com sucesso !
# Objeto salvo em: raw/posicao_veiculo/ano=2026/mes=01/dia=08/veiculo_013206.json
# linha executada com sucesso !
# Objeto salvo em: raw/posicao_veiculo/ano=2026/mes=01/dia=08/veiculo_013209.json
# linha executada com sucesso !
# Objeto salvo em: raw/posicao_veiculo/ano=2026/mes=01/dia=08/veiculo_013211.json
# linha executada com sucesso !
# Objeto salvo em: raw/posicao_veiculo/ano=2026/mes=01/dia=08/veiculo_013214.json
# linha executada com sucesso !
# Objeto salvo em: raw/posicao_veiculo/ano=2026/mes=01/dia=08/veiculo_013216.json
# linha executada com sucesso !
# Objeto salvo em: raw/posicao_veiculo/ano=2026/mes=01/dia=08/veiculo_013219.json
# linha executada com sucesso !
# Objeto salvo em: raw/posicao_veiculo/ano=2026/mes=01/dia=08/veiculo_013221.json
# linha executada com sucesso !
# Objeto salvo em: raw/posicao_veiculo/ano=2026/mes=01/dia=08/veiculo_013224.json
# linha executada com sucesso !
# Objeto salvo em: raw/posicao_veiculo/ano=2026/mes=01/dia=08/veiculo_013226.json
# linha executada com sucesso !
# Objeto salvo em: raw/posicao_veiculo/ano=2026/mes=01/dia=08/veiculo_013229.json
# linha executada com sucesso !
# Objeto salvo em: raw/posicao_veiculo/ano=2026/mes=01/dia=08/veiculo_013231.json
# linha executada com sucesso !
# Objeto salvo em: raw/posicao_veiculo/ano=2026/mes=01/dia=08/veiculo_013233.json
# linha executada com sucesso !
# Objeto salvo em: raw/posicao_veiculo/ano=2026/mes=01/dia=08/veiculo_013236.json
# linha executada com sucesso !
# Objeto salvo em: raw/posicao_veiculo/ano=2026/mes=01/dia=08/veiculo_013239.json
# linha executada com sucesso !
# Objeto salvo em: raw/posicao_veiculo/ano=2026/mes=01/dia=08/veiculo_013242.json
# linha executada com sucesso !
# Objeto salvo em: raw/posicao_veiculo/ano=2026/mes=01/dia=08/veiculo_013244.json
# linha executada com sucesso !
# Objeto salvo em: raw/posicao_veiculo/ano=2026/mes=01/dia=08/veiculo_013247.json
# linha executada com sucesso !
# Objeto salvo em: raw/posicao_veiculo/ano=2026/mes=01/dia=08/veiculo_013249.json
# linha executada com sucesso !
# Objeto salvo em: raw/posicao_veiculo/ano=2026/mes=01/dia=08/veiculo_013252.json
# linha executada com sucesso !
# Objeto salvo em: raw/posicao_veiculo/ano=2026/mes=01/dia=08/veiculo_013254.json
# linha executada com sucesso !
# Objeto salvo em: raw/posicao_veiculo/ano=2026/mes=01/dia=08/veiculo_013257.json
# linha executada com sucesso !
# Objeto salvo em: raw/posicao_veiculo/ano=2026/mes=01/dia=08/veiculo_013259.json
# linha executada com sucesso !
# Objeto salvo em: raw/posicao_veiculo/ano=2026/mes=01/dia=08/veiculo_013302.json
# linha executada com sucesso !
# Objeto salvo em: raw/posicao_veiculo/ano=2026/mes=01/dia=08/veiculo_013304.json
# linha executada com sucesso !
# Objeto salvo em: raw/posicao_veiculo/ano=2026/mes=01/dia=08/veiculo_013307.json
# linha executada com sucesso !
# Objeto salvo em: raw/posicao_veiculo/ano=2026/mes=01/dia=08/veiculo_013309.json
# linha executada com sucesso !
# Objeto salvo em: raw/posicao_veiculo/ano=2026/mes=01/dia=08/veiculo_013312.json
# linha executada com sucesso !
# Objeto salvo em: raw/posicao_veiculo/ano=2026/mes=01/dia=08/veiculo_013314.json
# linha executada com sucesso !
# Objeto salvo em: raw/posicao_veiculo/ano=2026/mes=01/dia=08/veiculo_013317.json
# linha executada com sucesso !
# Objeto salvo em: raw/posicao_veiculo/ano=2026/mes=01/dia=08/veiculo_013319.json
# linha executada com sucesso !
# Objeto salvo em: raw/posicao_veiculo/ano=2026/mes=01/dia=08/veiculo_013322.json
# linha executada com sucesso !
# Objeto salvo em: raw/posicao_veiculo/ano=2026/mes=01/dia=08/veiculo_013324.json
# linha executada com sucesso !
# Objeto salvo em: raw/posicao_veiculo/ano=2026/mes=01/dia=08/veiculo_013326.json
# linha executada com sucesso !
# Objeto salvo em: raw/posicao_veiculo/ano=2026/mes=01/dia=08/veiculo_013329.json
# linha executada com sucesso !
# Objeto salvo em: raw/posicao_veiculo/ano=2026/mes=01/dia=08/veiculo_013332.json
# linha executada com sucesso !
# Objeto salvo em: raw/posicao_veiculo/ano=2026/mes=01/dia=08/veiculo_013334.json
# linha executada com sucesso !

# %%
while True:
    lista_posicoes_veiculo = []
    previsao = previsao_por_parada(None, sessao, 'posicao')
    previsao_json = json.dumps(previsao)
    print("arquivo exportado com sucesso !")
    time.sleep(2)

# %%
df_veiculos = pd.DataFrame(lista_posicoes_veiculo[0]['l'])
for index, row in df_veiculos.iterrows():
    row['vs']
# Out:
#             c     cl  sl                    lt0               lt1  qv  \
# 0     737A-10  34498   2       TERM. STO. AMARO  TERM. JD. ÂNGELA  14
# 1     4115-10  33090   2      PÇA. DA REPÚBLICA   SHOP. PLAZA SUL   2
# 2     2678-10    383   1  TERM. PQ. D. PEDRO II       OLIVEIRINHA   5
# 3     7545-10  33272   2  PÇA. RAMOS DE AZEVEDO    JD. JOÃO XXIII   9
# 4     574R-10  34391   2            METRÔ BELÉM   TERM. SAPOPEMBA   4
# ...       ...    ...  ..                    ...               ...  ..
# 1976  7012-10   2043   1     TERM. GUARAPIRANGA       PQ. DO LAGO   1
# 1977  6826-10     16   1        TERM. CAPELINHA       JD. D. JOSÉ   1
# 1978  8062-10  33188   2                   LAPA  PQ. SÃO DOMINGOS   1
# 1979  1738-10    672   1          METRÔ SANTANA     VL. CONSTANÇA   1
# 1980  575A-10   1638   1    SHOP. METRÔ TATUAPÉ  DIV. SÃO CAETANO   1
#
#                                                      vs
# 0     [{'p': 73841, 'a': True, 'ta': '2026-01-08T00:...
# 1     [{'p': 52008, 'a': True, 'ta': '2026-01-08T00:...
# 2     [{'p': 32524, 'a': True, 'ta': '2026-01-08T00:...
# 3     [{'p': 81405, 'a': True, 'ta': '2026-01-08T00:...
# 4     [{'p': 56515, 'a': True, 'ta': '2026-01-08T00:...
# ...                                                 ...
# 1976  [{'p': 78902, 'a': True, 'ta': '2026-01-08T00:...
# 1977  [{'p': 72488, 'a': True, 'ta': '2026-01-08T00:...
# 1978  [{'p': 10425, 'a': True, 'ta': '2026-01-08T00:...
# 1979  [{'p': 26073, 'a': True, 'ta': '2026-01-08T00:...
# 1980  [{'p': 56524, 'a': True, 'ta': '2026-01-08T00:...
#
# [1981 rows x 7 columns]

# %%
pd.DataFrame(pd.DataFrame(lista_posicoes_veiculo[0]['l'])['vs'][0])
# Out:
#         p     a                    ta         py         px    sv    is
# 0   73841  True  2026-01-08T00:30:28Z -23.690655 -46.774252  None  None
# 1   73842  True  2026-01-08T00:30:45Z -23.690655 -46.774252  None  None
# 2   73004  True  2026-01-08T00:30:47Z -23.690655 -46.774252  None  None
# 3   73859  True  2026-01-08T00:30:51Z -23.666026 -46.715771  None  None
# 4   73833  True  2026-01-08T00:30:53Z -23.690655 -46.774252  None  None
# 5   73884  True  2026-01-08T00:30:51Z -23.654075 -46.711811  None  None
# 6   73910  True  2026-01-08T00:30:22Z -23.690355 -46.774400  None  None
# 7   73983  True  2026-01-08T00:30:30Z -23.690655 -46.774252  None  None
# 8   73810  True  2026-01-08T00:30:38Z -23.690655 -46.774252  None  None
# 9   73807  True  2026-01-08T00:30:49Z -23.690655 -46.774252  None  None
# 10  73919  True  2026-01-08T00:30:22Z -23.690655 -46.774252  None  None
# 11  73809  True  2026-01-08T00:30:36Z -23.675562 -46.754823  None  None
# 12  73854  True  2026-01-08T00:30:22Z -23.690655 -46.774252  None  None
# 13  73801  True  2026-01-08T00:30:42Z -23.690355 -46.774400  None  None

# %%
len(lista)
# Out:
# 22073

# %%
import time
from tqdm import tqdm

# Wrap any iterable with tqdm() to add a progress bar
for i in tqdm(range(100), desc="Processing"):

# %%
sessao = autenticar()  # autentica antes de começar
print("Autenticação realizada com sucesso !")

lista_respostas = []
id_linhas = []
previsoes = []
for i, parada in zip(range(len(lista_linhas)), lista_linhas):
    previsao = previsao_por_parada(parada, sessao, 'linha')
    lista_respostas.append(previsao)
    id_linhas.append(lista_respostas[i][0]['cl'])
    linha_atual = lista_respostas[i][0]['cl']
    previsao = previsao_por_parada(linha_atual,sessao,'previsao')
    previsoes.append(previsao)
    
    print(f"previsao para parada de id {parada} executada com sucesso !")
# Out:
# Autenticação realizada com sucesso !
# previsao para parada de id 476G-41 executada com sucesso !
# previsao para parada de id 6913-21 executada com sucesso !
# previsao para parada de id 695Y-42 executada com sucesso !
# previsao para parada de id 9701-10 executada com sucesso !
# previsao para parada de id N538-11 executada com sucesso !
# previsao para parada de id 233C-10 executada com sucesso !
# previsao para parada de id 5129-41 executada com sucesso !
# previsao para parada de id 5652-22 executada com sucesso !
# previsao para parada de id 7049-10 executada com sucesso !
# previsao para parada de id 8194-10 executada com sucesso !
# previsao para parada de id 9051-10 executada com sucesso !
# previsao para parada de id N602-11 executada com sucesso !
# previsao para parada de id 2019-10 executada com sucesso !
# previsao para parada de id 3001-10 executada com sucesso !
# previsao para parada de id 3032-10 executada com sucesso !
# previsao para parada de id 6012-10 executada com sucesso !
# previsao para parada de id 778R-10 executada com sucesso !
# previsao para parada de id 8017-10 executada com sucesso !
# previsao para parada de id 9014-10 executada com sucesso !
# previsao para parada de id 1178-31 executada com sucesso !
# previsao para parada de id 1780-10 executada com sucesso !
# previsao para parada de id 2719-10 executada com sucesso !
# previsao para parada de id 3731-10 executada com sucesso !
# previsao para parada de id 695X-22 executada com sucesso !
# previsao para parada de id 771P-10 executada com sucesso !
# previsao para parada de id 8538-10 executada com sucesso !
# previsao para parada de id 920P-10 executada com sucesso !
# previsao para parada de id 2018-10 executada com sucesso !
# previsao para parada de id 2100-10 executada com sucesso !
# previsao para parada de id 3002-10 executada com sucesso !
# previsao para parada de id 314J-10 executada com sucesso !
# previsao para parada de id 477A-10 executada com sucesso !
# previsao para parada de id N340-11 executada com sucesso !
# previsao para parada de id 1743-10 executada com sucesso !
# previsao para parada de id 524M-10 executada com sucesso !
# previsao para parada de id 971R-51 executada com sucesso !
# previsao para parada de id 128Y-10 executada com sucesso !
# previsao para parada de id 4005-10 executada com sucesso !
# previsao para parada de id 5164-10 executada com sucesso !
# previsao para parada de id 709A-10 executada com sucesso !
# previsao para parada de id 709G-10 executada com sucesso !
# previsao para parada de id 948A-10 executada com sucesso !
# previsao para parada de id 957T-10 executada com sucesso !
# previsao para parada de id 1024-10 executada com sucesso !
# previsao para parada de id 233A-10 executada com sucesso !
# previsao para parada de id 6000-10 executada com sucesso !
# previsao para parada de id 695Y-21 executada com sucesso !
# previsao para parada de id N745-11 executada com sucesso !
# previsao para parada de id 178Y-10 executada com sucesso !
# previsao para parada de id 2076-10 executada com sucesso !
# previsao para parada de id 4222-10 executada com sucesso !
# previsao para parada de id 546A-31 executada com sucesso !
# previsao para parada de id 5757-10 executada com sucesso !
# previsao para parada de id 6036-10 executada com sucesso !
# previsao para parada de id 778J-41 executada com sucesso !
# previsao para parada de id 807M-10 executada com sucesso !
# previsao para parada de id 9014-42 executada com sucesso !
# previsao para parada de id 1745-10 executada com sucesso !
# previsao para parada de id 3098-10 executada com sucesso !
# previsao para parada de id 314V-10 executada com sucesso !
# previsao para parada de id 4056-10 executada com sucesso !
# previsao para parada de id 502J-23 executada com sucesso !
# previsao para parada de id 574R-10 executada com sucesso !
# previsao para parada de id 6046-10 executada com sucesso !
# previsao para parada de id 748R-10 executada com sucesso !
# previsao para parada de id N438-11 executada com sucesso !
# previsao para parada de id 3161-10 executada com sucesso !
# previsao para parada de id 342M-10 executada com sucesso !
# previsao para parada de id 4014-10 executada com sucesso !
# previsao para parada de id 4053-10 executada com sucesso !
# previsao para parada de id 546J-31 executada com sucesso !
# previsao para parada de id 675K-10 executada com sucesso !
# previsao para parada de id 8705-51 executada com sucesso !
# previsao para parada de id CPTM L08 executada com sucesso !
# previsao para parada de id CPTM L10 executada com sucesso !
# previsao para parada de id N307-11 executada com sucesso !
# previsao para parada de id 175T-10 executada com sucesso !
# previsao para parada de id 4742-10 executada com sucesso !
# previsao para parada de id 5012-10 executada com sucesso !
# previsao para parada de id 5020-10 executada com sucesso !
# previsao para parada de id 6043-10 executada com sucesso !
# previsao para parada de id 9784-10 executada com sucesso !
# previsao para parada de id 4030-10 executada com sucesso !
# previsao para parada de id 6030-10 executada com sucesso !
# previsao para parada de id 3003-10 executada com sucesso !
# previsao para parada de id 4112-10 executada com sucesso !
# previsao para parada de id 5031-21 executada com sucesso !
# previsao para parada de id 6817-10 executada com sucesso !
# previsao para parada de id 8038-10 executada com sucesso !
# previsao para parada de id 178T-10 executada com sucesso !
# previsao para parada de id 271M-10 executada com sucesso !
# previsao para parada de id 3459-24 executada com sucesso !
# previsao para parada de id 5032-10 executada com sucesso !
# previsao para parada de id 5614-21 executada com sucesso !
# previsao para parada de id 6045-10 executada com sucesso !
# previsao para parada de id 746H-10 executada com sucesso !
# previsao para parada de id N837-11 executada com sucesso !
# previsao para parada de id 1019-10 executada com sucesso !
# previsao para parada de id 178L-10 executada com sucesso !
# previsao para parada de id 373T-10 executada com sucesso !
# previsao para parada de id 4051-10 executada com sucesso !
# previsao para parada de id 4210-10 executada com sucesso !
# previsao para parada de id 6080-10 executada com sucesso !
# previsao para parada de id 6200-10 executada com sucesso !
# previsao para parada de id 7053-10 executada com sucesso !
# previsao para parada de id 8677-10 executada com sucesso !
# previsao para parada de id 908T-10 executada com sucesso !
# previsao para parada de id N142-11 executada com sucesso !
# previsao para parada de id 3004-10 executada com sucesso !
# previsao para parada de id 4002-10 executada com sucesso !
# previsao para parada de id 4015-10 executada com sucesso !
# previsao para parada de id 5010-10 executada com sucesso !
# previsao para parada de id 6805-10 executada com sucesso !
# previsao para parada de id 8528-10 executada com sucesso !
# previsao para parada de id N701-11 executada com sucesso !
# previsao para parada de id 208M-10 executada com sucesso !
# previsao para parada de id 3134-10 executada com sucesso !
# previsao para parada de id 637G-10 executada com sucesso !
# previsao para parada de id 675G-22 executada com sucesso !
# previsao para parada de id 8545-10 executada com sucesso !
# previsao para parada de id 8615-10 executada com sucesso !
# previsao para parada de id 971D-10 executada com sucesso !
# previsao para parada de id N132-11 executada com sucesso !
# previsao para parada de id N505-11 executada com sucesso !
# previsao para parada de id 118Y-10 executada com sucesso !
# previsao para parada de id 3729-10 executada com sucesso !
# previsao para parada de id 3738-10 executada com sucesso !
# previsao para parada de id 3745-10 executada com sucesso !
# previsao para parada de id 6034-10 executada com sucesso !
# previsao para parada de id 6091-10 executada com sucesso !
# previsao para parada de id 702C-10 executada com sucesso !
# previsao para parada de id N431-11 executada com sucesso !
# previsao para parada de id N740-11 executada com sucesso !
# previsao para parada de id 1015-10 executada com sucesso !
# previsao para parada de id 2703-10 executada com sucesso !
# previsao para parada de id 6016-41 executada com sucesso !
# previsao para parada de id N139-11 executada com sucesso !
# previsao para parada de id 775A-10 executada com sucesso !
# previsao para parada de id 2582-10 executada com sucesso !
# previsao para parada de id 2707-10 executada com sucesso !
# previsao para parada de id 364A-10 executada com sucesso !
# previsao para parada de id 4037-10 executada com sucesso !
# previsao para parada de id 6L08-10 executada com sucesso !
# previsao para parada de id 502J-22 executada com sucesso !
# previsao para parada de id 6812-10 executada com sucesso !
# previsao para parada de id 7012-10 executada com sucesso !
# previsao para parada de id 7458-10 executada com sucesso !
# previsao para parada de id 8025-10 executada com sucesso !
# previsao para parada de id N842-11 executada com sucesso !
# previsao para parada de id 407Y-10 executada com sucesso !
# previsao para parada de id 527R-10 executada com sucesso !
# previsao para parada de id 6052-10 executada com sucesso !
# previsao para parada de id 516N-10 executada com sucesso !
# previsao para parada de id 5370-21 executada com sucesso !
# previsao para parada de id 573A-10 executada com sucesso !
# previsao para parada de id 6076-10 executada com sucesso !
# previsao para parada de id 695Y-41 executada com sucesso !
# previsao para parada de id N143-11 executada com sucesso !
# previsao para parada de id N232-11 executada com sucesso !
# previsao para parada de id N533-11 executada com sucesso !
# previsao para parada de id N802-11 executada com sucesso !
# previsao para parada de id 1758-10 executada com sucesso !
# previsao para parada de id 1788-10 executada com sucesso !
# previsao para parada de id 2017-10 executada com sucesso !
# previsao para parada de id 6820-31 executada com sucesso !
# previsao para parada de id 7050-10 executada com sucesso !
# previsao para parada de id N732-11 executada com sucesso !
# previsao para parada de id N843-11 executada com sucesso !
# previsao para parada de id 1742-10 executada com sucesso !
# previsao para parada de id 2707-31 executada com sucesso !
# previsao para parada de id 2735-10 executada com sucesso !
# previsao para parada de id 372U-10 executada com sucesso !
# previsao para parada de id 4716-10 executada com sucesso !
# previsao para parada de id 9018-10 executada com sucesso !
# previsao para parada de id N735-11 executada com sucesso !
# previsao para parada de id 172J-10 executada com sucesso !
# previsao para parada de id 177H-10 executada com sucesso !
# previsao para parada de id 1783-10 executada com sucesso !
# previsao para parada de id 2290-21 executada com sucesso !
# previsao para parada de id 3789-10 executada com sucesso !
# previsao para parada de id 5036-10 executada com sucesso !
# previsao para parada de id 6028-10 executada com sucesso !
# previsao para parada de id 6816-10 executada com sucesso !
# previsao para parada de id 847J-21 executada com sucesso !
# previsao para parada de id N507-11 executada com sucesso !
# previsao para parada de id N532-11 executada com sucesso !
# previsao para parada de id 1773-10 executada com sucesso !
# previsao para parada de id 3026-10 executada com sucesso !
# previsao para parada de id 6450-10 executada com sucesso !
# previsao para parada de id 675M-10 executada com sucesso !
# previsao para parada de id N402-11 executada com sucesso !
# previsao para parada de id 1702-10 executada com sucesso !
# previsao para parada de id 172P-10 executada com sucesso !
# previsao para parada de id 6012-31 executada com sucesso !
# previsao para parada de id N604-11 executada com sucesso !
# previsao para parada de id 177Y-10 executada com sucesso !
# previsao para parada de id 2033-10 executada com sucesso !
# previsao para parada de id 2105-21 executada com sucesso !
# previsao para parada de id 4708-10 executada com sucesso !
# previsao para parada de id 7055-10 executada com sucesso !
# previsao para parada de id 374M-10 executada com sucesso !
# previsao para parada de id 5632-21 executada com sucesso !
# previsao para parada de id 8700-10 executada com sucesso !
# previsao para parada de id N242-11 executada com sucesso !
# previsao para parada de id 407I-10 executada com sucesso !
# previsao para parada de id 576C-10 executada com sucesso !
# previsao para parada de id 607C-10 executada com sucesso !
# previsao para parada de id 6815-10 executada com sucesso !
# previsao para parada de id 715M-10 executada com sucesso !
# previsao para parada de id 8050-21 executada com sucesso !
# previsao para parada de id 1018-10 executada com sucesso !
# previsao para parada de id 3791-10 executada com sucesso !
# previsao para parada de id 4114-10 executada com sucesso !
# previsao para parada de id 6075-10 executada com sucesso !
# previsao para parada de id 7063-10 executada com sucesso !
# previsao para parada de id 809H-10 executada com sucesso !
# previsao para parada de id 857C-10 executada com sucesso !
# previsao para parada de id N134-11 executada com sucesso !
# previsao para parada de id N339-11 executada com sucesso !
# previsao para parada de id 2030-10 executada com sucesso !
# previsao para parada de id 2060-10 executada com sucesso !
# previsao para parada de id 2100-21 executada com sucesso !
# previsao para parada de id 4006-10 executada com sucesso !
# previsao para parada de id 4012-10 executada com sucesso !
# previsao para parada de id 5757-51 executada com sucesso !
# previsao para parada de id 7281-10 executada com sucesso !
# previsao para parada de id 856R-10 executada com sucesso !
# previsao para parada de id 2023-41 executada com sucesso !
# previsao para parada de id 3023-10 executada com sucesso !
# previsao para parada de id 5024-10 executada com sucesso !
# previsao para parada de id 6041-10 executada com sucesso !
# previsao para parada de id 6455-10 executada com sucesso !
# previsao para parada de id 6801-51 executada com sucesso !
# previsao para parada de id 8086-10 executada com sucesso !
# previsao para parada de id 877T-10 executada com sucesso !
# previsao para parada de id 909T-1 executada com sucesso !
# previsao para parada de id N743-11 executada com sucesso !
# previsao para parada de id 1787-10 executada com sucesso !
# previsao para parada de id 3064-10 executada com sucesso !
# previsao para parada de id 3737-10 executada com sucesso !
# previsao para parada de id 4732-31 executada com sucesso !
# previsao para parada de id 6062-51 executada com sucesso !
# previsao para parada de id 6072-21 executada com sucesso !
# previsao para parada de id 6826-10 executada com sucesso !
# previsao para parada de id 8072-10 executada com sucesso !
# previsao para parada de id 9047-10 executada com sucesso !
# previsao para parada de id 271A-51 executada com sucesso !
# previsao para parada de id 354M-10 executada com sucesso !
# previsao para parada de id 5018-10 executada com sucesso !
# previsao para parada de id 965A-10 executada com sucesso !
# previsao para parada de id 1020-10 executada com sucesso !
# previsao para parada de id 2058-10 executada com sucesso !
# previsao para parada de id 2732-10 executada com sucesso !
# previsao para parada de id 5178-10 executada com sucesso !
# previsao para parada de id 546L-10 executada com sucesso !
# previsao para parada de id 675I-10 executada com sucesso !
# previsao para parada de id 714C-10 executada com sucesso !
# previsao para parada de id N502-11 executada com sucesso !
# previsao para parada de id N636-11 executada com sucesso !
# previsao para parada de id 2708-10 executada com sucesso !
# previsao para parada de id 6010-10 executada com sucesso !
# previsao para parada de id 6291-10 executada com sucesso !
# previsao para parada de id 675L-10 executada com sucesso !
# previsao para parada de id 8017-21 executada com sucesso !
# previsao para parada de id 875P-10 executada com sucesso !
# previsao para parada de id 9354-10 executada com sucesso !
# previsao para parada de id 971R-42 executada com sucesso !
# previsao para parada de id METRÔ L5 executada com sucesso !
# previsao para parada de id N834-11 executada com sucesso !
# previsao para parada de id 2735-21 executada com sucesso !
# previsao para parada de id 374V-10 executada com sucesso !
# previsao para parada de id 607A-21 executada com sucesso !
# previsao para parada de id 6258-10 executada com sucesso !
# previsao para parada de id 6L10-41 executada com sucesso !
# previsao para parada de id N239-11 executada com sucesso !
# previsao para parada de id 1896-10 executada com sucesso !
# previsao para parada de id 514T-10 executada com sucesso !
# previsao para parada de id 6804-10 executada com sucesso !
# previsao para parada de id 745M-21 executada com sucesso !
# previsao para parada de id N437-11 executada com sucesso !
# previsao para parada de id 2720-31 executada com sucesso !
# previsao para parada de id 4115-10 executada com sucesso !
# previsao para parada de id 5194-10 executada com sucesso !
# previsao para parada de id 695Y-23 executada com sucesso !
# previsao para parada de id 9188-42 executada com sucesso !
# previsao para parada de id N601-11 executada com sucesso !
# previsao para parada de id 1722-10 executada com sucesso !
# previsao para parada de id 1778-10 executada com sucesso !
# previsao para parada de id 407W-10 executada com sucesso !
# previsao para parada de id 702U-22 executada com sucesso !
# previsao para parada de id 627J-10 executada com sucesso !
# previsao para parada de id 8015-10 executada com sucesso !
# previsao para parada de id 846M-10 executada com sucesso !
# previsao para parada de id 9785-51 executada com sucesso !
# previsao para parada de id 5702-10 executada com sucesso !
# previsao para parada de id 1744-10 executada com sucesso !
# previsao para parada de id 3069-21 executada com sucesso !
# previsao para parada de id 5143-10 executada com sucesso !
# previsao para parada de id 6358-10 executada com sucesso !
# previsao para parada de id 7006-10 executada com sucesso !
# previsao para parada de id N206-11 executada com sucesso !
# previsao para parada de id N705-11 executada com sucesso !
# previsao para parada de id N706-11 executada com sucesso !
# previsao para parada de id 3063-10 executada com sucesso !
# previsao para parada de id 307C-10 executada com sucesso !
# previsao para parada de id 3301-10 executada com sucesso !
# previsao para parada de id 3773-10 executada com sucesso !
# previsao para parada de id 4092-10 executada com sucesso !
# previsao para parada de id 6035-21 executada com sucesso !
# previsao para parada de id 8002-10 executada com sucesso !
# previsao para parada de id 819A-10 executada com sucesso !
# previsao para parada de id 2720-10 executada com sucesso !
# previsao para parada de id 2765-10 executada com sucesso !
# previsao para parada de id 2780-10 executada com sucesso !
# previsao para parada de id 3734-10 executada com sucesso !
# previsao para parada de id 3789-51 executada com sucesso !
# previsao para parada de id 4491-21 executada com sucesso !
# previsao para parada de id 577T-10 executada com sucesso !
# previsao para parada de id 637A-22 executada com sucesso !
# previsao para parada de id 6L03-10 executada com sucesso !
# previsao para parada de id 6L04-41 executada com sucesso !
# previsao para parada de id 7005-51 executada com sucesso !
# previsao para parada de id 707K-10 executada com sucesso !
# previsao para parada de id 9009-10 executada com sucesso !
# previsao para parada de id N434-11 executada com sucesso !
# previsao para parada de id 2730-10 executada com sucesso !
# previsao para parada de id 4717-10 executada com sucesso !
# previsao para parada de id 5145-10 executada com sucesso !
# previsao para parada de id 7009-10 executada com sucesso !
# previsao para parada de id 119L-10 executada com sucesso !
# previsao para parada de id 2703-22 executada com sucesso !
# previsao para parada de id 2722-10 executada com sucesso !
# previsao para parada de id 3712-51 executada com sucesso !
# previsao para parada de id 778J-10 executada com sucesso !
# previsao para parada de id N801-11 executada com sucesso !
# previsao para parada de id 2029-10 executada com sucesso !
# previsao para parada de id 342N-10 executada com sucesso !
# previsao para parada de id 6031-10 executada com sucesso !
# previsao para parada de id 627M-10 executada com sucesso !
# previsao para parada de id 6803-10 executada com sucesso !
# previsao para parada de id 7051-10 executada com sucesso !
# previsao para parada de id N504-11 executada com sucesso !
# previsao para parada de id N744-11 executada com sucesso !
# previsao para parada de id 2034-10 executada com sucesso !
# previsao para parada de id 2363-10 executada com sucesso !
# previsao para parada de id 6078-10 executada com sucesso !
# previsao para parada de id 8007-10 executada com sucesso !
# previsao para parada de id N836-11 executada com sucesso !
# previsao para parada de id 106A-10 executada com sucesso !
# previsao para parada de id 1178-10 executada com sucesso !
# previsao para parada de id 1772-10 executada com sucesso !
# previsao para parada de id 2031-10 executada com sucesso !
# previsao para parada de id 273N-10 executada com sucesso !
# previsao para parada de id 476G-10 executada com sucesso !
# previsao para parada de id 6037-10 executada com sucesso !
# previsao para parada de id 6120-10 executada com sucesso !
# previsao para parada de id 9188-10 executada com sucesso !
# previsao para parada de id N401-11 executada com sucesso !
# previsao para parada de id 407I-21 executada com sucesso !
# previsao para parada de id 5632-51 executada com sucesso !
# previsao para parada de id 6039-10 executada com sucesso !
# previsao para parada de id 677A-10 executada com sucesso !
# previsao para parada de id 7002-10 executada com sucesso !
# previsao para parada de id 7267-10 executada com sucesso !
# previsao para parada de id 1014-10 executada com sucesso !
# previsao para parada de id 6063-10 executada com sucesso !
# previsao para parada de id 607M-10 executada com sucesso !
# previsao para parada de id 8001-10 executada com sucesso !
# previsao para parada de id 875H-10 executada com sucesso !
# previsao para parada de id N637-11 executada com sucesso !
# previsao para parada de id 172X-10 executada com sucesso !
# previsao para parada de id 5290-10 executada com sucesso !
# previsao para parada de id 6042-22 executada com sucesso !
# previsao para parada de id 2023-10 executada com sucesso !
# previsao para parada de id 278A-10 executada com sucesso !
# previsao para parada de id 390E-41 executada com sucesso !
# previsao para parada de id 4732-10 executada com sucesso !
# previsao para parada de id 6002-10 executada com sucesso !
# previsao para parada de id 707A-10 executada com sucesso !
# previsao para parada de id 7545-10 executada com sucesso !
# previsao para parada de id N103-11 executada com sucesso !
# previsao para parada de id N432-11 executada com sucesso !
# previsao para parada de id 1767-10 executada com sucesso !
# previsao para parada de id 5164-21 executada com sucesso !
# previsao para parada de id 5175-10 executada com sucesso !
# previsao para parada de id 7053-21 executada com sucesso !
# previsao para parada de id 8003-10 executada com sucesso !
# previsao para parada de id 9006-10 executada com sucesso !
# previsao para parada de id 3761-10 executada com sucesso !
# previsao para parada de id 5110-21 executada com sucesso !
# previsao para parada de id 6051-31 executada com sucesso !
# previsao para parada de id METRÔ L3 executada com sucesso !
# previsao para parada de id N141-11 executada com sucesso !
# previsao para parada de id N603-11 executada com sucesso !
# previsao para parada de id 273R-10 executada com sucesso !
# previsao para parada de id 2769-10 executada com sucesso !
# previsao para parada de id 3741-10 executada com sucesso !
# previsao para parada de id 546L-41 executada com sucesso !
# previsao para parada de id 6116-10 executada com sucesso !
# previsao para parada de id 7001-10 executada com sucesso !
# previsao para parada de id 9191-21 executada com sucesso !
# previsao para parada de id N133-11 executada com sucesso !
# previsao para parada de id N207-11 executada com sucesso !
# previsao para parada de id 1012-21 executada com sucesso !
# previsao para parada de id 129F-10 executada com sucesso !
# previsao para parada de id 2005-10 executada com sucesso !
# previsao para parada de id 351F-10 executada com sucesso !
# previsao para parada de id 5632-10 executada com sucesso !
# previsao para parada de id 6019-10 executada com sucesso !
# previsao para parada de id 6071-10 executada com sucesso !
# previsao para parada de id 8100-10 executada com sucesso !
# previsao para parada de id N506-11 executada com sucesso !
# previsao para parada de id 1703-10 executada com sucesso !
# previsao para parada de id 263C-10 executada com sucesso !
# previsao para parada de id 3737-31 executada com sucesso !
# previsao para parada de id 637A-26 executada com sucesso !
# previsao para parada de id N640-11 executada com sucesso !
# previsao para parada de id 121G-10 executada com sucesso !
# previsao para parada de id 2734-10 executada com sucesso !
# previsao para parada de id 390E-10 executada com sucesso !
# previsao para parada de id 4726-10 executada com sucesso !
# previsao para parada de id 5021-10 executada com sucesso !
# previsao para parada de id 5123-10 executada com sucesso !
# previsao para parada de id 7057-10 executada com sucesso !
# previsao para parada de id 1026-10 executada com sucesso !
# previsao para parada de id 1775-10 executada com sucesso !
# previsao para parada de id 2590-10 executada com sucesso !
# previsao para parada de id 3539-10 executada com sucesso !
# previsao para parada de id 3725-10 executada com sucesso !
# previsao para parada de id 5033-10 executada com sucesso !
# previsao para parada de id 6232-10 executada com sucesso !
# previsao para parada de id 6960-10 executada com sucesso !
# previsao para parada de id 6L05-10 executada com sucesso !
# previsao para parada de id 8707-21 executada com sucesso !
# previsao para parada de id 958P-10 executada com sucesso !
# previsao para parada de id METRÔ L1 executada com sucesso !
# previsao para parada de id 1017-10 executada com sucesso !
# previsao para parada de id 2009-10 executada com sucesso !
# previsao para parada de id 2059-10 executada com sucesso !
# previsao para parada de id 6013-10 executada com sucesso !
# previsao para parada de id 6062-10 executada com sucesso !
# previsao para parada de id 809J-10 executada com sucesso !
# previsao para parada de id 9785-10 executada com sucesso !
# previsao para parada de id N440-11 executada com sucesso !
# previsao para parada de id N739-11 executada com sucesso !
# previsao para parada de id 1720-21 executada com sucesso !
# previsao para parada de id 1788-31 executada com sucesso !
# previsao para parada de id 4004-10 executada com sucesso !
# previsao para parada de id 5127-10 executada com sucesso !
# previsao para parada de id 6110-10 executada com sucesso !
# previsao para parada de id 6500-10 executada com sucesso !
# previsao para parada de id 546A-10 executada com sucesso !
# previsao para parada de id 546J-10 executada com sucesso !
# previsao para parada de id 7062-31 executada com sucesso !
# previsao para parada de id 807A-10 executada com sucesso !
# previsao para parada de id 8594-10 executada com sucesso !
# previsao para parada de id 297A-10 executada com sucesso !
# previsao para parada de id 5110-24 executada com sucesso !
# previsao para parada de id 517J-10 executada com sucesso !
# previsao para parada de id 647A-10 executada com sucesso !
# previsao para parada de id 746R-10 executada com sucesso !
# previsao para parada de id 9717-10 executada com sucesso !
# previsao para parada de id N135-11 executada com sucesso !
# previsao para parada de id N441-11 executada com sucesso !
# previsao para parada de id 2016-10 executada com sucesso !
# previsao para parada de id 273V-10 executada com sucesso !
# previsao para parada de id 4033-10 executada com sucesso !
# previsao para parada de id 4087-10 executada com sucesso !
# previsao para parada de id 5013-10 executada com sucesso !
# previsao para parada de id 5018-31 executada com sucesso !
# previsao para parada de id 647P-10 executada com sucesso !
# previsao para parada de id 736G-10 executada com sucesso !
# previsao para parada de id N140-11 executada com sucesso !
# previsao para parada de id N231-11 executada com sucesso !
# previsao para parada de id 1760-10 executada com sucesso !
# previsao para parada de id 513C-31 executada com sucesso !
# previsao para parada de id 6051-10 executada com sucesso !
# previsao para parada de id 6818-10 executada com sucesso !
# previsao para parada de id 7060-10 executada com sucesso !
# previsao para parada de id 8319-10 executada com sucesso !
# previsao para parada de id 1756-10 executada com sucesso !
# previsao para parada de id 2552-10 executada com sucesso !
# previsao para parada de id 5024-31 executada com sucesso !
# previsao para parada de id 5110-10 executada com sucesso !
# previsao para parada de id 6250-10 executada com sucesso !
# previsao para parada de id 7725-10 executada com sucesso !
# previsao para parada de id CPTM L07 executada com sucesso !
# previsao para parada de id N738-11 executada com sucesso !
# previsao para parada de id 2762-10 executada com sucesso !
# previsao para parada de id 3462-10 executada com sucesso !
# previsao para parada de id 574A-10 executada com sucesso !
# previsao para parada de id 8009-10 executada com sucesso !
# previsao para parada de id 2004-10 executada com sucesso !
# previsao para parada de id 2702-21 executada com sucesso !
# previsao para parada de id 3686-21 executada com sucesso !
# previsao para parada de id 414P-10 executada com sucesso !
# previsao para parada de id 4734-21 executada com sucesso !
# previsao para parada de id 9005-10 executada com sucesso !
# previsao para parada de id N233-11 executada com sucesso !
# previsao para parada de id 2714-10 executada com sucesso !
# previsao para parada de id 5630-21 executada com sucesso !
# previsao para parada de id 5759-31 executada com sucesso !
# previsao para parada de id 6262-10 executada com sucesso !
# previsao para parada de id 695H-10 executada com sucesso !
# previsao para parada de id 7023-10 executada com sucesso !
# previsao para parada de id 7181-10 executada com sucesso !
# previsao para parada de id 2021-10 executada com sucesso !
# previsao para parada de id 209P-1 executada com sucesso !
# previsao para parada de id 2451-10 executada com sucesso !
# previsao para parada de id 4221-10 executada com sucesso !
# previsao para parada de id 476A-10 executada com sucesso !
# previsao para parada de id 6052-31 executada com sucesso !
# previsao para parada de id 6083-10 executada com sucesso !
# previsao para parada de id 6093-10 executada com sucesso !
# previsao para parada de id 7016-10 executada com sucesso !
# previsao para parada de id 8019-31 executada com sucesso !
# previsao para parada de id N303-11 executada com sucesso !
# previsao para parada de id N404-11 executada com sucesso !
# previsao para parada de id 5317-10 executada com sucesso !
# previsao para parada de id 5370-10 executada com sucesso !
# previsao para parada de id 6056-10 executada com sucesso !
# previsao para parada de id 8010-21 executada com sucesso !
# previsao para parada de id 4310-21 executada com sucesso !
# previsao para parada de id 5128-10 executada com sucesso !
# previsao para parada de id 8028-10 executada com sucesso !
# previsao para parada de id 848L-10 executada com sucesso !
# previsao para parada de id 9002-10 executada com sucesso !
# previsao para parada de id 475R-10 executada com sucesso !
# previsao para parada de id 509M-10 executada com sucesso !
# previsao para parada de id 5131-10 executada com sucesso !
# previsao para parada de id 5362-10 executada com sucesso !
# previsao para parada de id N406-11 executada com sucesso !
# previsao para parada de id 1206-10 executada com sucesso !
# previsao para parada de id 3054-10 executada com sucesso !
# previsao para parada de id 3414-10 executada com sucesso !
# previsao para parada de id 6072-10 executada com sucesso !
# previsao para parada de id 736I-10 executada com sucesso !
# previsao para parada de id 930P-10 executada com sucesso !
# previsao para parada de id 1021-10 executada com sucesso !
# previsao para parada de id 373M-10 executada com sucesso !
# previsao para parada de id 524L-10 executada com sucesso !
# previsao para parada de id 6099-10 executada com sucesso !
# previsao para parada de id 917H-10 executada com sucesso !
# previsao para parada de id 971C-10 executada com sucesso !
# previsao para parada de id N736-11 executada com sucesso !
# previsao para parada de id 2006-10 executada com sucesso !
# previsao para parada de id 2678-10 executada com sucesso !
# previsao para parada de id 3160-10 executada com sucesso !
# previsao para parada de id 403A-10 executada com sucesso !
# previsao para parada de id 4718-10 executada com sucesso !
# previsao para parada de id 5110-23 executada com sucesso !
# previsao para parada de id 606Y-10 executada com sucesso !
# previsao para parada de id 6412-10 executada com sucesso !
# previsao para parada de id 677Y-10 executada com sucesso !
# previsao para parada de id 8047-51 executada com sucesso !
# previsao para parada de id N202-11 executada com sucesso !
# previsao para parada de id 5038-10 executada com sucesso !
# previsao para parada de id 5103-10 executada com sucesso !
# previsao para parada de id 6015-10 executada com sucesso !
# previsao para parada de id 6091-21 executada com sucesso !
# previsao para parada de id 695X-10 executada com sucesso !
# previsao para parada de id 8018-10 executada com sucesso !
# previsao para parada de id 8021-10 executada com sucesso !
# previsao para parada de id 8600-10 executada com sucesso !
# previsao para parada de id 888P-10 executada com sucesso !
# previsao para parada de id 9008-41 executada com sucesso !
# previsao para parada de id 971M-10 executada com sucesso !
# previsao para parada de id 478P-10 executada com sucesso !
# previsao para parada de id 509J-10 executada com sucesso !
# previsao para parada de id 6069-10 executada com sucesso !
# previsao para parada de id 6403-10 executada com sucesso !
# previsao para parada de id 8020-10 executada com sucesso !
# previsao para parada de id 857A-10 executada com sucesso !
# previsao para parada de id 9004-10 executada com sucesso !
# previsao para parada de id 9011-10 executada com sucesso !
# previsao para parada de id 1705-10 executada com sucesso !
# previsao para parada de id 175P-10 executada com sucesso !
# previsao para parada de id 3029-10 executada com sucesso !
# previsao para parada de id 6053-10 executada com sucesso !
# previsao para parada de id 6451-10 executada com sucesso !
# previsao para parada de id 695D-10 executada com sucesso !
# previsao para parada de id 6813-10 executada com sucesso !
# previsao para parada de id 702U-10 executada com sucesso !
# previsao para parada de id N831-11 executada com sucesso !
# previsao para parada de id N835-11 executada com sucesso !
# previsao para parada de id 4016-10 executada com sucesso !
# previsao para parada de id 4035-10 executada com sucesso !
# previsao para parada de id 4310-10 executada com sucesso !
# previsao para parada de id 5705-10 executada com sucesso !
# previsao para parada de id 6820-10 executada com sucesso !
# previsao para parada de id 695Y-10 executada com sucesso !
# previsao para parada de id 8705-10 executada com sucesso !
# previsao para parada de id 9050-10 executada com sucesso !
# previsao para parada de id N703-11 executada com sucesso !
# previsao para parada de id 148P-10 executada com sucesso !
# previsao para parada de id 1786-10 executada com sucesso !
# previsao para parada de id 2127-10 executada com sucesso !
# previsao para parada de id 2290-10 executada com sucesso !
# previsao para parada de id 425E-10 executada com sucesso !
# previsao para parada de id 5034-31 executada com sucesso !
# previsao para parada de id 5106-10 executada com sucesso !
# previsao para parada de id 857P-10 executada com sucesso !
# previsao para parada de id 875C-10 executada com sucesso !
# previsao para parada de id 917M-31 executada com sucesso !
# previsao para parada de id N742-11 executada com sucesso !
# previsao para parada de id 1701-22 executada com sucesso !
# previsao para parada de id 2715-10 executada com sucesso !
# previsao para parada de id 273D-10 executada com sucesso !
# previsao para parada de id 3778-10 executada com sucesso !
# previsao para parada de id 5362-23 executada com sucesso !
# previsao para parada de id 6825-10 executada com sucesso !
# previsao para parada de id 809T-10 executada com sucesso !
# previsao para parada de id 172K-10 executada com sucesso !
# previsao para parada de id 2716-10 executada com sucesso !
# previsao para parada de id 273X-10 executada com sucesso !
# previsao para parada de id 3098-31 executada com sucesso !
# previsao para parada de id 3686-10 executada com sucesso !
# previsao para parada de id 4085-10 executada com sucesso !
# previsao para parada de id 7011-10 executada com sucesso !
# previsao para parada de id 7272-10 executada com sucesso !
# previsao para parada de id 775P-10 executada com sucesso !
# previsao para parada de id 8055-10 executada com sucesso !
# previsao para parada de id 9162-10 executada com sucesso !
# previsao para parada de id N304-11 executada com sucesso !
# previsao para parada de id N838-11 executada com sucesso !
# previsao para parada de id 253F-10 executada com sucesso !
# previsao para parada de id 4006-21 executada com sucesso !
# previsao para parada de id 5614-10 executada com sucesso !
# previsao para parada de id 6072-23 executada com sucesso !
# previsao para parada de id 6414-10 executada com sucesso !
# previsao para parada de id 8686-10 executada com sucesso !
# previsao para parada de id N403-11 executada com sucesso !
# previsao para parada de id 2772-10 executada com sucesso !
# previsao para parada de id 3459-10 executada com sucesso !
# previsao para parada de id 407A-21 executada com sucesso !
# previsao para parada de id 6338-10 executada com sucesso !
# previsao para parada de id 746P-10 executada com sucesso !
# previsao para parada de id 1178-32 executada com sucesso !
# previsao para parada de id 2710-10 executada com sucesso !
# previsao para parada de id 5391-22 executada com sucesso !
# previsao para parada de id 609F-21 executada com sucesso !
# previsao para parada de id 1177-31 executada com sucesso !
# previsao para parada de id 1785-10 executada com sucesso !
# previsao para parada de id 2032-10 executada com sucesso !
# previsao para parada de id 271A-10 executada com sucesso !
# previsao para parada de id 3735-21 executada com sucesso !
# previsao para parada de id 5034-10 executada com sucesso !
# previsao para parada de id 5391-10 executada com sucesso !
# previsao para parada de id 6073-10 executada com sucesso !
# previsao para parada de id 675G-41 executada com sucesso !
# previsao para parada de id 6840-10 executada com sucesso !
# previsao para parada de id N301-11 executada com sucesso !
# previsao para parada de id 4028-10 executada com sucesso !
# previsao para parada de id 4709-10 executada com sucesso !
# previsao para parada de id 513L-10 executada com sucesso !
# previsao para parada de id 6L02-10 executada com sucesso !
# previsao para parada de id 7245-10 executada com sucesso !
# previsao para parada de id 9166-10 executada com sucesso !
# previsao para parada de id N344-11 executada com sucesso !
# previsao para parada de id 178Y-21 executada com sucesso !
# previsao para parada de id 6063-42 executada com sucesso !
# previsao para parada de id 6115-41 executada com sucesso !
# previsao para parada de id 756A-10 executada com sucesso !
# previsao para parada de id N204-11 executada com sucesso !
# previsao para parada de id N334-11 executada com sucesso !
# previsao para parada de id N439-11 executada com sucesso !
# previsao para parada de id 475M-10 executada com sucesso !
# previsao para parada de id 5318-10 executada com sucesso !
# previsao para parada de id 669A-10 executada com sucesso !
# previsao para parada de id 701A-10 executada com sucesso !
# previsao para parada de id 7059-10 executada com sucesso !
# previsao para parada de id 9011-21 executada com sucesso !
# previsao para parada de id N131-11 executada com sucesso !
# previsao para parada de id 6115-10 executada com sucesso !
# previsao para parada de id 6913-10 executada com sucesso !
# previsao para parada de id 2704-10 executada com sucesso !
# previsao para parada de id 2712-10 executada com sucesso !
# previsao para parada de id 3009-10 executada com sucesso !
# previsao para parada de id 4010-10 executada com sucesso !
# previsao para parada de id 4315-10 executada com sucesso !
# previsao para parada de id 5035-10 executada com sucesso !
# previsao para parada de id 519M-10 executada com sucesso !
# previsao para parada de id 6006-10 executada com sucesso !
# previsao para parada de id 8605-10 executada com sucesso !
# previsao para parada de id 2552-41 executada com sucesso !
# previsao para parada de id 4286-10 executada com sucesso !
# previsao para parada de id N405-11 executada com sucesso !
# previsao para parada de id N741-11 executada com sucesso !
# previsao para parada de id N746-11 executada com sucesso !
# previsao para parada de id 407E-10 executada com sucesso !
# previsao para parada de id 807P-10 executada com sucesso !
# previsao para parada de id 9032-21 executada com sucesso !
# previsao para parada de id N305-11 executada com sucesso !
# previsao para parada de id 1177-10 executada com sucesso !
# previsao para parada de id 189L-21 executada com sucesso !
# previsao para parada de id 6042-21 executada com sucesso !
# previsao para parada de id 746V-10 executada com sucesso !
# previsao para parada de id 857R-41 executada com sucesso !
# previsao para parada de id METRÔ L4 executada com sucesso !
# previsao para parada de id N306-11 executada com sucesso !
# previsao para parada de id N342-11 executada com sucesso !
# previsao para parada de id 4008-10 executada com sucesso !
# previsao para parada de id 5091-10 executada com sucesso !
# previsao para parada de id 5759-10 executada com sucesso !
# previsao para parada de id 605A-10 executada com sucesso !
# previsao para parada de id 637A-10 executada com sucesso !
# previsao para parada de id 6823-10 executada com sucesso !
# previsao para parada de id 7011-31 executada com sucesso !
# previsao para parada de id 8047-10 executada com sucesso !
# previsao para parada de id N531-11 executada com sucesso !
# previsao para parada de id 179X-10 executada com sucesso !
# previsao para parada de id 5141-10 executada com sucesso !
# previsao para parada de id 6076-41 executada com sucesso !
# previsao para parada de id 719R-10 executada com sucesso !
# previsao para parada de id 746K-10 executada com sucesso !
# previsao para parada de id 8016-10 executada com sucesso !
# previsao para parada de id 847J-10 executada com sucesso !
# previsao para parada de id 172Y-10 executada com sucesso !
# previsao para parada de id 6422-10 executada com sucesso !
# previsao para parada de id 7017-10 executada com sucesso !
# previsao para parada de id 8024-10 executada com sucesso !
# previsao para parada de id 8055-51 executada com sucesso !
# previsao para parada de id 807J-10 executada com sucesso !
# previsao para parada de id 8600-22 executada com sucesso !
# previsao para parada de id 3902-10 executada com sucesso !
# previsao para parada de id 4312-21 executada com sucesso !
# previsao para parada de id 573T-31 executada com sucesso !
# previsao para parada de id 6L04-42 executada com sucesso !
# previsao para parada de id 8029-10 executada com sucesso !
# previsao para parada de id 8082-10 executada com sucesso !
# previsao para parada de id 938C-21 executada com sucesso !
# previsao para parada de id 107T-10 executada com sucesso !
# previsao para parada de id 2551-10 executada com sucesso !
# previsao para parada de id 3112-10 executada com sucesso !
# previsao para parada de id 4027-10 executada com sucesso !
# previsao para parada de id 476G-21 executada com sucesso !
# previsao para parada de id 6505-10 executada com sucesso !
# previsao para parada de id 6837-10 executada com sucesso !
# previsao para parada de id 695V-10 executada com sucesso !
# previsao para parada de id 8073-10 executada com sucesso !
# previsao para parada de id 809U-10 executada com sucesso !
# previsao para parada de id 9090-10 executada com sucesso !
# previsao para parada de id N534-11 executada com sucesso !
# previsao para parada de id 1178-33 executada com sucesso !
# previsao para parada de id 1709-10 executada com sucesso !
# previsao para parada de id 2523-10 executada com sucesso !
# previsao para parada de id 3064-41 executada com sucesso !
# previsao para parada de id 3763-10 executada com sucesso !
# previsao para parada de id 390E-42 executada com sucesso !
# previsao para parada de id 4734-10 executada com sucesso !
# previsao para parada de id 7040-10 executada com sucesso !
# previsao para parada de id 8700-24 executada com sucesso !
# previsao para parada de id 9300-10 executada com sucesso !
# previsao para parada de id N839-11 executada com sucesso !
# previsao para parada de id 5015-10 executada com sucesso !
# previsao para parada de id 6092-10 executada com sucesso !
# previsao para parada de id 8026-10 executada com sucesso !
# previsao para parada de id 978T-10 executada com sucesso !
# previsao para parada de id N205-11 executada com sucesso !
# previsao para parada de id 2028-10 executada com sucesso !
# previsao para parada de id 263J-10 executada com sucesso !
# previsao para parada de id 5029-10 executada com sucesso !
# previsao para parada de id 211V-10 executada com sucesso !
# previsao para parada de id 342C-10 executada com sucesso !
# previsao para parada de id 4036-10 executada com sucesso !
# previsao para parada de id 847P-42 executada com sucesso !
# previsao para parada de id 3006-10 executada com sucesso !
# previsao para parada de id 3722-10 executada com sucesso !
# previsao para parada de id 805L-10 executada com sucesso !
# previsao para parada de id 955P-10 executada com sucesso !
# previsao para parada de id 574A-21 executada com sucesso !
# previsao para parada de id 6806-10 executada com sucesso !
# previsao para parada de id 8019-10 executada com sucesso !
# previsao para parada de id 119C-10 executada com sucesso !
# previsao para parada de id 2678-41 executada com sucesso !
# previsao para parada de id 6003-21 executada com sucesso !
# previsao para parada de id 637R-10 executada com sucesso !
# previsao para parada de id 8686-21 executada com sucesso !
# previsao para parada de id 177H-21 executada com sucesso !
# previsao para parada de id 3010-10 executada com sucesso !
# previsao para parada de id 4031-10 executada com sucesso !
# previsao para parada de id 407M-10 executada com sucesso !
# previsao para parada de id 4288-10 executada com sucesso !
# previsao para parada de id 4313-10 executada com sucesso !
# previsao para parada de id 5105-10 executada com sucesso !
# previsao para parada de id 5194-21 executada com sucesso !
# previsao para parada de id 2710-31 executada com sucesso !
# previsao para parada de id 2726-10 executada com sucesso !
# previsao para parada de id 4086-10 executada com sucesso !
# previsao para parada de id 477U-10 executada com sucesso !
# previsao para parada de id N336-11 executada com sucesso !
# previsao para parada de id 2703-21 executada com sucesso !
# previsao para parada de id 3462-41 executada com sucesso !
# previsao para parada de id 6008-10 executada com sucesso !
# previsao para parada de id 675K-23 executada com sucesso !
# previsao para parada de id 8010-10 executada com sucesso !
# previsao para parada de id N631-11 executada com sucesso !
# previsao para parada de id 9181-10 executada com sucesso !
# previsao para parada de id N235-11 executada com sucesso !
# previsao para parada de id N238-11 executada com sucesso !
# previsao para parada de id 2161-10 executada com sucesso !
# previsao para parada de id 407G-10 executada com sucesso !
# previsao para parada de id 507T-10 executada com sucesso !
# previsao para parada de id 6091-51 executada com sucesso !
# previsao para parada de id 626A-10 executada com sucesso !
# previsao para parada de id 675G-10 executada com sucesso !
# previsao para parada de id 971R-10 executada com sucesso !
# previsao para parada de id N540-11 executada com sucesso !
# previsao para parada de id 271F-10 executada com sucesso !
# previsao para parada de id 2756-10 executada com sucesso !
# previsao para parada de id 3046-10 executada com sucesso !
# previsao para parada de id 3728-41 executada com sucesso !
# ...
# previsao para parada de id 2080-10 executada com sucesso !
# previsao para parada de id 273G-21 executada com sucesso !
# previsao para parada de id 4093-10 executada com sucesso !
# previsao para parada de id 2626-10 executada com sucesso !
# previsao para parada de id 3206-10 executada com sucesso !
# previsao para parada de id 3718-10 executada com sucesso !
# previsao para parada de id 575A-10 executada com sucesso !
# previsao para parada de id 6055-10 executada com sucesso !
# previsao para parada de id 8199-10 executada com sucesso !
# previsao para parada de id 938V-10 executada com sucesso !
# previsao para parada de id 9653-10 executada com sucesso !
# previsao para parada de id N332-11 executada com sucesso !
# previsao para parada de id N734-11 executada com sucesso !
# previsao para parada de id 2088-10 executada com sucesso !
# previsao para parada de id 2203-10 executada com sucesso !
# previsao para parada de id 3051-10 executada com sucesso !
# previsao para parada de id 4025-10 executada com sucesso !
# previsao para parada de id 148L-10 executada com sucesso !
# previsao para parada de id 2725-10 executada com sucesso !
# previsao para parada de id 2755-10 executada com sucesso !
# previsao para parada de id 637A-21 executada com sucesso !
# previsao para parada de id 6970-10 executada com sucesso !
# previsao para parada de id 7550-10 executada com sucesso !
# previsao para parada de id 1759-10 executada com sucesso !
# previsao para parada de id 2123-10 executada com sucesso !
# previsao para parada de id 3768-10 executada com sucesso !
# previsao para parada de id 4113-10 executada com sucesso !
# previsao para parada de id 4735-10 executada com sucesso !
# previsao para parada de id 701H-10 executada com sucesso !
# previsao para parada de id 857R-10 executada com sucesso !
# previsao para parada de id 938C-10 executada com sucesso !
# previsao para parada de id CPTM L12 executada com sucesso !
# previsao para parada de id 1738-10 executada com sucesso !
# previsao para parada de id 5119-23 executada com sucesso !
# previsao para parada de id 6084-10 executada com sucesso !
# previsao para parada de id 809L-10 executada com sucesso !
# previsao para parada de id 875A-10 executada com sucesso !
# previsao para parada de id 971X-10 executada com sucesso !
# previsao para parada de id N335-11 executada com sucesso !
# previsao para parada de id 3069-10 executada com sucesso !
# previsao para parada de id 3390-10 executada com sucesso !
# previsao para parada de id 3721-41 executada com sucesso !
# previsao para parada de id 372F-10 executada com sucesso !
# previsao para parada de id 4032-10 executada com sucesso !
# previsao para parada de id 4725-10 executada com sucesso !
# previsao para parada de id 6036-51 executada com sucesso !
# previsao para parada de id 938P-10 executada com sucesso !
# previsao para parada de id 2724-10 executada com sucesso !
# previsao para parada de id 3139-10 executada com sucesso !
# previsao para parada de id 3736-10 executada com sucesso !
# previsao para parada de id 6022-10 executada com sucesso !
# previsao para parada de id 817C-10 executada com sucesso !
# previsao para parada de id 3796-10 executada com sucesso !
# previsao para parada de id 5100-10 executada com sucesso !
# previsao para parada de id 5106-31 executada com sucesso !
# previsao para parada de id 5119-22 executada com sucesso !
# previsao para parada de id 6L01-23 executada com sucesso !
# previsao para parada de id 8548-10 executada com sucesso !
# previsao para parada de id 2013-10 executada com sucesso !
# previsao para parada de id 2582-21 executada com sucesso !
# previsao para parada de id 3031-10 executada com sucesso !
# previsao para parada de id 4027-41 executada com sucesso !
# previsao para parada de id 5107-10 executada com sucesso !
# previsao para parada de id 6805-31 executada com sucesso !
# previsao para parada de id 8000-10 executada com sucesso !
# previsao para parada de id 809D-10 executada com sucesso !
# previsao para parada de id 9015-31 executada com sucesso !
# previsao para parada de id N737-11 executada com sucesso !
# previsao para parada de id 407H-10 executada com sucesso !
# previsao para parada de id 6008-41 executada com sucesso !
# previsao para parada de id 6041-21 executada com sucesso !
# previsao para parada de id 8200-10 executada com sucesso !
# previsao para parada de id 909T-10 executada com sucesso !
# previsao para parada de id N535-11 executada com sucesso !
# previsao para parada de id N833-11 executada com sucesso !
# previsao para parada de id 1709-21 executada com sucesso !
# previsao para parada de id 273L-10 executada com sucesso !
# previsao para parada de id 3459-21 executada com sucesso !
# previsao para parada de id 4029-10 executada com sucesso !
# previsao para parada de id 5108-10 executada com sucesso !
# previsao para parada de id 574J-10 executada com sucesso !
# previsao para parada de id 6039-21 executada com sucesso !
# previsao para parada de id 7903-10 executada com sucesso !
# previsao para parada de id 8008-10 executada com sucesso !
# previsao para parada de id 9500-10 executada com sucesso !
# previsao para parada de id N245-11 executada com sucesso !
# previsao para parada de id N407-11 executada com sucesso !
# previsao para parada de id N503-11 executada com sucesso !
# previsao para parada de id 1765-10 executada com sucesso !
# previsao para parada de id 2012-10 executada com sucesso !
# previsao para parada de id 2182-10 executada com sucesso !
# previsao para parada de id 5028-10 executada com sucesso !
# previsao para parada de id 8004-10 executada com sucesso !
# previsao para parada de id 8083-10 executada com sucesso !
# previsao para parada de id N635-11 executada com sucesso !
# previsao para parada de id N841-11 executada com sucesso !
# previsao para parada de id 3013-10 executada com sucesso !
# previsao para parada de id 3766-10 executada com sucesso !
# previsao para parada de id 4011-10 executada com sucesso !
# previsao para parada de id 4017-10 executada com sucesso !
# previsao para parada de id 5031-10 executada com sucesso !
# previsao para parada de id 6L11-10 executada com sucesso !
# previsao para parada de id 8012-10 executada com sucesso !
# previsao para parada de id 917M-10 executada com sucesso !
# previsao para parada de id METRÔ L2 executada com sucesso !
# previsao para parada de id N634-11 executada com sucesso !
# previsao para parada de id 1705-51 executada com sucesso !
# previsao para parada de id 2666-10 executada com sucesso !
# previsao para parada de id 2718-10 executada com sucesso !
# previsao para parada de id 273J-10 executada com sucesso !
# previsao para parada de id 5154-10 executada com sucesso !
# previsao para parada de id 6001-10 executada com sucesso !
# previsao para parada de id 9020-10 executada com sucesso !
# previsao para parada de id 9023-10 executada com sucesso !
# previsao para parada de id N536-11 executada com sucesso !
# previsao para parada de id 8400-10 executada com sucesso !
# previsao para parada de id CPTM L09 executada com sucesso !
# previsao para parada de id 178A-10 executada com sucesso !
# previsao para parada de id 3099-10 executada com sucesso !
# previsao para parada de id N731-11 executada com sucesso !
# previsao para parada de id 3795-10 executada com sucesso !
# previsao para parada de id 4003-10 executada com sucesso !
# previsao para parada de id 609J-10 executada com sucesso !
# previsao para parada de id 8252-10 executada com sucesso !
# previsao para parada de id 576M-10 executada com sucesso !
# previsao para parada de id 8013-10 executada com sucesso !
# previsao para parada de id 8700-1 executada com sucesso !
# previsao para parada de id 875C-1 executada com sucesso !
# previsao para parada de id 2711-10 executada com sucesso !
# previsao para parada de id 407A-10 executada com sucesso !
# previsao para parada de id 606Z-10 executada com sucesso !
# previsao para parada de id 677V-10 executada com sucesso !
# previsao para parada de id 7006-51 executada com sucesso !
# previsao para parada de id 8060-10 executada com sucesso !
# previsao para parada de id 971T-10 executada com sucesso !
# previsao para parada de id 701U-10 executada com sucesso !
# previsao para parada de id 1720-10 executada com sucesso !
# previsao para parada de id 3725-41 executada com sucesso !
# previsao para parada de id 373L-10 executada com sucesso !
# previsao para parada de id 5026-10 executada com sucesso !
# previsao para parada de id 6016-10 executada com sucesso !
# previsao para parada de id 7004-22 executada com sucesso !
# previsao para parada de id 8300-1 executada com sucesso !
# previsao para parada de id 9191-10 executada com sucesso !
# previsao para parada de id 1016-10 executada com sucesso !
# previsao para parada de id 2666-21 executada com sucesso !
# previsao para parada de id 273R-42 executada com sucesso !
# previsao para parada de id 3063-1 executada com sucesso !
# previsao para parada de id 408A-10 executada com sucesso !
# previsao para parada de id 5011-10 executada com sucesso !
# previsao para parada de id 6058-10 executada com sucesso !
# previsao para parada de id 7022-10 executada com sucesso !
# previsao para parada de id 809A-10 executada com sucesso !
# previsao para parada de id 809N-10 executada com sucesso !
# previsao para parada de id 8215-10 executada com sucesso !
# previsao para parada de id 9032-10 executada com sucesso !
# previsao para parada de id 938L-10 executada com sucesso !
# previsao para parada de id N106-11 executada com sucesso !
# previsao para parada de id 3712-10 executada com sucesso !
# previsao para parada de id 8075-21 executada com sucesso !
# previsao para parada de id N244-11 executada com sucesso !
# previsao para parada de id 1701-10 executada com sucesso !
# previsao para parada de id 4729-10 executada com sucesso !
# previsao para parada de id 675X-10 executada com sucesso !
# previsao para parada de id N101-11 executada com sucesso !
# previsao para parada de id 5013-31 executada com sucesso !
# previsao para parada de id 6061-10 executada com sucesso !
# previsao para parada de id 637P-10 executada com sucesso !
# previsao para parada de id 8006-10 executada com sucesso !
# previsao para parada de id 809P-10 executada com sucesso !
# previsao para parada de id 189L-10 executada com sucesso !
# previsao para parada de id 2727-10 executada com sucesso !
# previsao para parada de id 6475-10 executada com sucesso !
# previsao para parada de id 748A-10 executada com sucesso !
# previsao para parada de id 8050-10 executada com sucesso !
# previsao para parada de id 8622-10 executada com sucesso !
# previsao para parada de id N236-11 executada com sucesso !
# previsao para parada de id 118C-10 executada com sucesso !
# previsao para parada de id 5025-10 executada com sucesso !
# previsao para parada de id 8700-21 executada com sucesso !
# previsao para parada de id N237-11 executada com sucesso !
# previsao para parada de id N704-11 executada com sucesso !
# previsao para parada de id 607A-10 executada com sucesso !
# previsao para parada de id 7021-10 executada com sucesso !
# previsao para parada de id 8043-10 executada com sucesso !
# previsao para parada de id N241-11 executada com sucesso !
# previsao para parada de id 273G-10 executada com sucesso !
# previsao para parada de id 502J-21 executada com sucesso !
# previsao para parada de id 546T-10 executada com sucesso !
# previsao para parada de id 6026-10 executada com sucesso !
# previsao para parada de id 6049-10 executada com sucesso !
# previsao para parada de id 606C-10 executada com sucesso !
# previsao para parada de id 6L05-21 executada com sucesso !
# previsao para parada de id 7411-10 executada com sucesso !
# previsao para parada de id 9019-10 executada com sucesso !
# previsao para parada de id N331-11 executada com sucesso !
# previsao para parada de id 2010-10 executada com sucesso !
# previsao para parada de id 271C-10 executada com sucesso !
# previsao para parada de id 311C-10 executada com sucesso !
# previsao para parada de id 7062-10 executada com sucesso !
# previsao para parada de id 4007-10 executada com sucesso !
# previsao para parada de id 4052-10 executada com sucesso !
# previsao para parada de id 2020-10 executada com sucesso !
# previsao para parada de id 2101-10 executada com sucesso !
# previsao para parada de id 407R-10 executada com sucesso !
# previsao para parada de id 4314-21 executada com sucesso !
# previsao para parada de id 5752-10 executada com sucesso !
# previsao para parada de id 5791-10 executada com sucesso !
# previsao para parada de id 6L04-10 executada com sucesso !
# previsao para parada de id 9501-10 executada com sucesso !
# previsao para parada de id N341-11 executada com sucesso !
# previsao para parada de id 3735-10 executada com sucesso !
# previsao para parada de id 3762-10 executada com sucesso !
# previsao para parada de id 4314-10 executada com sucesso !
# previsao para parada de id 4724-10 executada com sucesso !
# previsao para parada de id 5362-21 executada com sucesso !
# previsao para parada de id 637V-10 executada com sucesso !
# previsao para parada de id 8707-10 executada com sucesso !
# previsao para parada de id 4491-10 executada com sucesso !
# previsao para parada de id 6020-10 executada com sucesso !
# previsao para parada de id 274P-10 executada com sucesso !
# previsao para parada de id 5701-10 executada com sucesso !
# previsao para parada de id 6013-21 executada com sucesso !
# previsao para parada de id 6063-43 executada com sucesso !
# previsao para parada de id 8549-10 executada com sucesso !
# previsao para parada de id 2026-10 executada com sucesso !
# previsao para parada de id 2722-31 executada com sucesso !
# previsao para parada de id 3015-10 executada com sucesso !
# previsao para parada de id 7016-21 executada com sucesso !
# previsao para parada de id 975A-10 executada com sucesso !
# previsao para parada de id N537-11 executada com sucesso !
# previsao para parada de id N840-11 executada com sucesso !
# previsao para parada de id 3743-10 executada com sucesso !
# previsao para parada de id 407L-10 executada com sucesso !
# previsao para parada de id 967A-10 executada com sucesso !
# previsao para parada de id N733-11 executada com sucesso !
# previsao para parada de id 2705-10 executada com sucesso !
# previsao para parada de id 2767-10 executada com sucesso !
# previsao para parada de id 4008-21 executada com sucesso !
# previsao para parada de id 6L10-10 executada com sucesso !
# previsao para parada de id 1783-22 executada com sucesso !
# previsao para parada de id 3024-10 executada com sucesso !
# previsao para parada de id 637J-10 executada com sucesso !
# previsao para parada de id 8050-31 executada com sucesso !
# previsao para parada de id 2709-10 executada com sucesso !
# previsao para parada de id 3732-10 executada com sucesso !
# previsao para parada de id 7004-10 executada com sucesso !
# previsao para parada de id 8300-10 executada com sucesso !
# previsao para parada de id 847P-10 executada com sucesso !
# previsao para parada de id 1771-10 executada com sucesso !
# previsao para parada de id 5652-10 executada com sucesso !
# previsao para parada de id 8062-10 executada com sucesso !
# previsao para parada de id 9789-10 executada com sucesso !
# previsao para parada de id N104-11 executada com sucesso !
# previsao para parada de id N302-11 executada com sucesso !
# previsao para parada de id 2008-10 executada com sucesso !
# previsao para parada de id 2717-10 executada com sucesso !
# previsao para parada de id 2731-10 executada com sucesso !
# previsao para parada de id 4019-10 executada com sucesso !
# previsao para parada de id 407P-10 executada com sucesso !
# previsao para parada de id 6027-10 executada com sucesso !
# previsao para parada de id 6400-10 executada com sucesso !
# previsao para parada de id 8610-10 executada com sucesso !
# previsao para parada de id CPTM L11 executada com sucesso !
# previsao para parada de id N203-11 executada com sucesso !
# previsao para parada de id N702-11 executada com sucesso !
# previsao para parada de id 273F-10 executada com sucesso !
# previsao para parada de id 3006-21 executada com sucesso !
# previsao para parada de id 648P-10 executada com sucesso !
# previsao para parada de id 8014-10 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !

# %%
df_linhas = pd.read_parquet(r'tabela_linhas.parquet')
df_linhas
# Out:
#      id_linha
# 0        1112
# 1        1549
# 2        2632
# 3         569
# 4        2390
# ...       ...
# 1340      159
# 1341     2550
# 1342       66
# 1343      801
# 1344     2323
#
# [1345 rows x 1 columns]

# %%
sessao = autenticar()  # autentica antes de começar
print("Autenticação realizada com sucesso !")

previsoes = []
for index, row in df_linhas.iterrows():
    previsao = previsao_por_parada(row['id_linha'],sessao,'previsao')
    previsoes.append(previsao)
    
    print(f"previsao para parada de id {parada} executada com sucesso !")
# Out:
# Autenticação realizada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# ...
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !
# previsao para parada de id N234-11 executada com sucesso !

# %%
pd.DataFrame(previsoes[2]['ps'])
# Out:
#            cp                          np         py         px  \
# 0   560009166        ALFREDO REIMBERG B/C -23.790935 -46.726858
# 1   560009201  AMARO ALVES DO ROSARIO B/C -23.814648 -46.735225
# 2   560009175            ANA CAROLINA B/C -23.803805 -46.734790
# 3   560009171             BALTAZARINI B/C -23.798989 -46.731158
# 4   560009162       ELEVATÓRIA SABESP B/C -23.780240 -46.724711
# 5   560009173        ESTRADA DO PAIOL B/C -23.801170 -46.733875
# 6   560009170       ESTRADA DO PINHAL B/C -23.793253 -46.729063
# 7     5614545           EUZÉBIO COGHI B/C -23.826443 -46.732218
# 8   560009192           JOSÉ LA TORRE B/C -23.806909 -46.736403
# 9   560009159    JOSÉ NICOLAU DE LIMA B/C -23.777013 -46.722914
# 10    5614543                    JUZA B/C -23.822356 -46.735702
# 11  560009197              LUÍZ BUENO B/C -23.811252 -46.736391
# 12  560009165       NIELS C. SORENSEN B/C -23.786102 -46.726012
# 13    5614561                 RAVELLO B/C -23.824717 -46.734245
# 14  560009194             ROMÃO BOETA B/C -23.808968 -46.736957
# 15  560009232          SATÉLITE ARIEL B/C -23.773112 -46.720299
# 16  560009203                SERVIDÃO B/C -23.817602 -46.734311
#
#                                                    vs
# 0   [{'p': '61796', 't': '21:27', 'a': True, 'ta':...
# 1   [{'p': '61796', 't': '21:14', 'a': True, 'ta':...
# 2   [{'p': '61796', 't': '21:19', 'a': True, 'ta':...
# 3   [{'p': '61796', 't': '21:22', 'a': True, 'ta':...
# 4   [{'p': '61574', 't': '21:14', 'a': True, 'ta':...
# 5   [{'p': '61796', 't': '21:20', 'a': True, 'ta':...
# 6   [{'p': '61796', 't': '21:25', 'a': True, 'ta':...
# 7                                                  []
# 8   [{'p': '61796', 't': '21:18', 'a': True, 'ta':...
# 9   [{'p': '61574', 't': '21:16', 'a': True, 'ta':...
# 10                                                 []
# 11  [{'p': '61796', 't': '21:15', 'a': True, 'ta':...
# 12  [{'p': '61796', 't': '21:28', 'a': True, 'ta':...
# 13                                                 []
# 14  [{'p': '61796', 't': '21:16', 'a': True, 'ta':...
# 15  [{'p': '61574', 't': '21:18', 'a': True, 'ta':...
# 16  [{'p': '61796', 't': '21:13', 'a': True, 'ta':...

# %%
import pandas as pd
pd.DataFrame([str(i) for i in id_linhas],columns=['id_linha']).to_parquet(r'tabela_linhas.parquet')

# %%
pd.DataFrame(previsoes[1]['ps'])
# Out:
#            cp                                  np         py         px  vs
# 0   230009867                          BARRAL B/C -23.739261 -46.701430  []
# 1   230009868                   BELMIRA MARIN B/C -23.734540 -46.698876  []
# 2   230009858               CRISTIAN ANDERSEN B/C -23.757982 -46.714700  []
# 3   230009962                  DOMENICO LAURO C/B -23.717209 -46.704407  []
# 4   230009860                      DOS MENDES B/C -23.750864 -46.710384  []
# 5   530015348                      EUCALIPTOS B/C -23.604788 -46.675035  []
# 6   230009864                         HILÁRIO B/C -23.744767 -46.707007  []
# 7   230009844                         HILÁRIO C/B -23.744971 -46.707070  []
# 8   810009943                  JOÃO DE BARROS B/C -23.676013 -46.712366  []
# 9   810009951              LEONARDO DE FASSIO B/C -23.693558 -46.714792  []
# 10  230009870                   LOUREIRO ROSA B/C -23.728978 -46.698816  []
# 11  230009861                       LUÍS ROTA B/C -23.747413 -46.707998  []
# 12  810009945                   MAR DEL PLATA B/C -23.680203 -46.713075  []
# 13  230009957                   MÁRIO MARTINS B/C -23.710603 -46.711260  []
# 14  810009950                         NICOLAU B/C -23.688202 -46.714573  []
# 15  230009960                          PAPINI B/C -23.713754 -46.708494  []
# 16  720015730              PARADA 1 - BANESPA B/C -23.630024 -46.689940  []
# 17  150015738              PARADA 1 - MORUMBI B/C -23.623506 -46.685293  []
# 18  340015750             PARADA 1 - PORTUGAL B/C -23.611994 -46.677742  []
# 19  720015734    PARADA 1 - ROQUE PETRONI JR. B/C -23.626917 -46.687740  []
# 20  340015746     PARADA 1 - VIEIRA DE MORAIS B/C -23.616119 -46.680142  []
# 21  810009964     PARADA 2 - LARGO DO SOCORRO B/C -23.666568 -46.711984  []
# 22    5306702          Parada Afonso Braz - B/C 1 -23.593046 -46.672803  []
# 23  810009941            PARADA DOS INOCENTES B/C -23.672073 -46.712195  []
# 24  530015327  PARADA J.K.  B/C (ACESSO AO ITAIM) -23.585198 -46.670511  []
# 25  810009956                     PARANÓPOLIS B/C -23.701070 -46.715025  []
# 26  810009954                     PORTO ARTUR B/C -23.696421 -46.714903  []
# 27  810009948                   PRIMO TISSELI B/C -23.684024 -46.714410  []
# 28  230009829     RIO BONITO ESQUERDA B/C CENTRAL -23.718230 -46.698916  []
# 29  230009836               RODRIGUES VILARES C/B -23.727900 -46.699209  []
# 30  230009866                   SÃO FRANCISCO C/B -23.740637 -46.704266  []

# %%
lista_repostas[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[76], line 1
# ----> 1 lista_repostas[0]
#
# NameError: name 'lista_repostas' is not defined

# %%
import pandas as pd
import json

lista_respostas[0][0]
# Out:
# 2632
